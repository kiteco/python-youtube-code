# %%
# Importing modules
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
# Reading in the data
tesla = pd.read_csv('TSLA.csv')

# %%
tesla.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
# Isolating the date and close price
tesla = tesla[['Date', 'Close']]

# %%
tesla.head()
# Out:
#          Date      Close
# 0  2010-06-29  23.889999
# 1  2010-06-30  23.830000
# 2  2010-07-01  21.959999
# 3  2010-07-02  19.200001
# 4  2010-07-06  16.110001

# %%
# Converting the date series to a datetime object
tesla.Date = pd.to_datetime(tesla.Date, format = '%Y/%m/%d')

# %%
# Setting the index 
plot_tesla = tesla.set_index('Date')

# %% [markdown]
# # Plot of the Tesla stock price dataset

# %%
plot_tesla['Close'].plot(figsize=(16,6))

# %% [markdown]
# # Selecting the portion of dataset we want to predict
# Upon visual inspection, the time series is roughly stationary from the period of 2014 through the end of 2016, so let's reduce the dataset to 2014 through 2016. Stationarity means that the time series has a constant mean and variance over a certain time horizon.
#
# Start date: 1/1/14 -> index = 884
#
# End date: 12/31/16 -> index = 1639

# %%
new_tesla = tesla.loc[884:1639]

# %%
new_tesla.head()
# Out:
#           Date       Close
# 884 2014-01-02  150.100006
# 885 2014-01-03  149.559998
# 886 2014-01-06  147.000000
# 887 2014-01-07  149.360001
# 888 2014-01-08  151.279999

# %%
new_tesla.tail()
# Out:
#            Date       Close
# 1635 2016-12-23  213.339996
# 1636 2016-12-27  219.529999
# 1637 2016-12-28  219.740005
# 1638 2016-12-29  214.679993
# 1639 2016-12-30  213.690002

# %% [markdown]
# # Feature Preprocessing
# Below, we apply a min-max scaler to the dataset, and then convert it to a supervised learning problem. Basically, you can visualize the conversion in terms of a "sliding window", that divides the dataset into many different windows of length 20 days, that allow us to predict the 21st day. As the window slides from left to right, we are able to use a LSTM model to predict a "future" day from 20 preceding days.
#
# ## Min-max Scaling and Train/Test Split

# %%
new_tesla = new_tesla.drop('Date', axis = 1)
new_tesla = new_tesla.reset_index(drop = True)
new_tesla.head()
T = new_tesla.values
T = T.astype('float32')
T = np.reshape(T, (-1, 1))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))
T = scaler.fit_transform(T)

# 80-20 split
train_size = int(len(T) * 0.80)
test_size = int(len(T) - train_size)
train, test = T[0:train_size,:], T[train_size:len(T),:]

# %%
# Method for create features from the time series data
def create_features(data, window_size):
    X, Y = [], []
    for i in range(len(data) - window_size - 1):
        window = data[i:(i + window_size), 0]
        X.append(window)
        Y.append(data[i + window_size, 0])
    return np.array(X), np.array(Y)

# Roughly one month of trading assuming 5 trading days per week
window_size = 20
X_train, Y_train = create_features(train, window_size)

X_test, Y_test = create_features(test, window_size)

# Reshape to the format of [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))

X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
# Checking to make sure that none of our training set is leaking into the testing set
T_shape = T.shape
train_shape = train.shape
test_shape = test.shape

# Make sure that the number of rows in the dataset = train rows + test rows
def isLeak(T_shape, train_shape, test_shape):
    return not(T_shape[0] == (train_shape[0] + test_shape[0]))

print(isLeak(T_shape, train_shape, test_shape))
# Out:
# False

# %%
# Model imports
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks.callbacks import ModelCheckpoint

# %%
# Setting seed for reproducibility 
tf.random.set_seed(11)
np.random.seed(11)

# %% [markdown]
# # Building the  LSTM RNN Model
# Below, we build a LSTM model that consists of one LSTM layer with a density of 50 neurons and a RELU activation function, as well as a Dropout regularization layer. We add a model checkpoint that is looking to minimize the validation set's loss. We save each model that consists of a lower validation loss compared to any model that came before it.

# %%
# Building model
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', #return_sequences = True, 
               input_shape = (X_train.shape[1], window_size)))
model.add(Dropout(0.2))

model.add(Dense(1, activation = 'linear'))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')

# %%
filepath = 'saved_models/model_epoch_{epoch:02d}.hdf5'

checkpoint = ModelCheckpoint(filepath = filepath,
                             monitor = 'val_loss',
                             verbose = 1,
                             save_best_only = True,
                             mode ='min'
                            )

history = model.fit(X_train, Y_train, epochs = 100, batch_size = 20, validation_data = (X_test, Y_test), 
                    callbacks = [checkpoint], 
                    verbose = 1, shuffle = False)

model.summary()
# Out:
# Train on 583 samples, validate on 131 samples
# Epoch 1/100
# 583/583 [==============================] - 2s 4ms/step - loss: 0.1189 - val_loss: 0.0046
#
# Epoch 00001: val_loss improved from inf to 0.00464, saving model to saved_models/model_epoch_01.hdf5
# Epoch 2/100
# 583/583 [==============================] - 0s 265us/step - loss: 0.0238 - val_loss: 0.0047
#
# Epoch 00002: val_loss did not improve from 0.00464
# Epoch 3/100
# 583/583 [==============================] - 0s 252us/step - loss: 0.0174 - val_loss: 0.0037
#
# Epoch 00003: val_loss improved from 0.00464 to 0.00366, saving model to saved_models/model_epoch_03.hdf5
# Epoch 4/100
# 583/583 [==============================] - 0s 262us/step - loss: 0.0170 - val_loss: 0.0041
#
# Epoch 00004: val_loss did not improve from 0.00366
# Epoch 5/100
# 583/583 [==============================] - 0s 261us/step - loss: 0.0180 - val_loss: 0.0030
#
# Epoch 00005: val_loss improved from 0.00366 to 0.00303, saving model to saved_models/model_epoch_05.hdf5
# Epoch 6/100
# 583/583 [==============================] - 0s 282us/step - loss: 0.0142 - val_loss: 0.0028
#
# Epoch 00006: val_loss improved from 0.00303 to 0.00275, saving model to saved_models/model_epoch_06.hdf5
# Epoch 7/100
# 583/583 [==============================] - 0s 265us/step - loss: 0.0133 - val_loss: 0.0026
#
# Epoch 00007: val_loss improved from 0.00275 to 0.00265, saving model to saved_models/model_epoch_07.hdf5
# Epoch 8/100
# 583/583 [==============================] - 0s 267us/step - loss: 0.0130 - val_loss: 0.0023
#
# Epoch 00008: val_loss improved from 0.00265 to 0.00227, saving model to saved_models/model_epoch_08.hdf5
# Epoch 9/100
# 583/583 [==============================] - 0s 266us/step - loss: 0.0118 - val_loss: 0.0022
#
# Epoch 00009: val_loss improved from 0.00227 to 0.00217, saving model to saved_models/model_epoch_09.hdf5
# Epoch 10/100
# 583/583 [==============================] - 0s 265us/step - loss: 0.0119 - val_loss: 0.0022
#
# Epoch 00010: val_loss did not improve from 0.00217
# Epoch 11/100
# 583/583 [==============================] - 0s 292us/step - loss: 0.0113 - val_loss: 0.0020
#
# Epoch 00011: val_loss improved from 0.00217 to 0.00204, saving model to saved_models/model_epoch_11.hdf5
# Epoch 12/100
# 583/583 [==============================] - 0s 278us/step - loss: 0.0108 - val_loss: 0.0020
#
# Epoch 00012: val_loss did not improve from 0.00204
# Epoch 13/100
# 583/583 [==============================] - 0s 268us/step - loss: 0.0105 - val_loss: 0.0019
#
# Epoch 00013: val_loss improved from 0.00204 to 0.00187, saving model to saved_models/model_epoch_13.hdf5
# Epoch 14/100
# 583/583 [==============================] - 0s 274us/step - loss: 0.0085 - val_loss: 0.0018
#
# Epoch 00014: val_loss improved from 0.00187 to 0.00182, saving model to saved_models/model_epoch_14.hdf5
# Epoch 15/100
# 583/583 [==============================] - 0s 268us/step - loss: 0.0106 - val_loss: 0.0020
#
# Epoch 00015: val_loss did not improve from 0.00182
# Epoch 16/100
# 583/583 [==============================] - 0s 265us/step - loss: 0.0095 - val_loss: 0.0018
#
# Epoch 00016: val_loss did not improve from 0.00182
# Epoch 17/100
# 583/583 [==============================] - 0s 285us/step - loss: 0.0092 - val_loss: 0.0018
#
# Epoch 00017: val_loss improved from 0.00182 to 0.00175, saving model to saved_models/model_epoch_17.hdf5
# Epoch 18/100
# 583/583 [==============================] - 0s 271us/step - loss: 0.0091 - val_loss: 0.0018
#
# Epoch 00018: val_loss did not improve from 0.00175
# Epoch 19/100
# 583/583 [==============================] - 0s 284us/step - loss: 0.0092 - val_loss: 0.0017
#
# Epoch 00019: val_loss improved from 0.00175 to 0.00175, saving model to saved_models/model_epoch_19.hdf5
# Epoch 20/100
# 583/583 [==============================] - 0s 274us/step - loss: 0.0092 - val_loss: 0.0018
#
# Epoch 00020: val_loss did not improve from 0.00175
# Epoch 21/100
# 583/583 [==============================] - 0s 277us/step - loss: 0.0094 - val_loss: 0.0020
#
# Epoch 00021: val_loss did not improve from 0.00175
# Epoch 22/100
# 583/583 [==============================] - 0s 327us/step - loss: 0.0095 - val_loss: 0.0019
#
# Epoch 00022: val_loss did not improve from 0.00175
# Epoch 23/100
# 583/583 [==============================] - 0s 295us/step - loss: 0.0089 - val_loss: 0.0018
#
# Epoch 00023: val_loss did not improve from 0.00175
# Epoch 24/100
# 583/583 [==============================] - 0s 270us/step - loss: 0.0087 - val_loss: 0.0017
#
# Epoch 00024: val_loss improved from 0.00175 to 0.00170, saving model to saved_models/model_epoch_24.hdf5
# Epoch 25/100
# 583/583 [==============================] - 0s 272us/step - loss: 0.0088 - val_loss: 0.0020
#
# Epoch 00025: val_loss did not improve from 0.00170
# Epoch 26/100
# 583/583 [==============================] - 0s 304us/step - loss: 0.0084 - val_loss: 0.0016
#
# Epoch 00026: val_loss improved from 0.00170 to 0.00159, saving model to saved_models/model_epoch_26.hdf5
# Epoch 27/100
# 583/583 [==============================] - 0s 351us/step - loss: 0.0085 - val_loss: 0.0016
#
# Epoch 00027: val_loss improved from 0.00159 to 0.00159, saving model to saved_models/model_epoch_27.hdf5
# Epoch 28/100
# 583/583 [==============================] - 0s 393us/step - loss: 0.0082 - val_loss: 0.0017
#
# Epoch 00028: val_loss did not improve from 0.00159
# Epoch 29/100
# 583/583 [==============================] - 0s 319us/step - loss: 0.0084 - val_loss: 0.0016
#
# Epoch 00029: val_loss did not improve from 0.00159
# Epoch 30/100
# 583/583 [==============================] - 0s 330us/step - loss: 0.0090 - val_loss: 0.0016
#
# Epoch 00030: val_loss improved from 0.00159 to 0.00157, saving model to saved_models/model_epoch_30.hdf5
# Epoch 31/100
# 583/583 [==============================] - 0s 352us/step - loss: 0.0084 - val_loss: 0.0016
#
# Epoch 00031: val_loss improved from 0.00157 to 0.00156, saving model to saved_models/model_epoch_31.hdf5
# Epoch 32/100
# 583/583 [==============================] - 0s 384us/step - loss: 0.0078 - val_loss: 0.0017
#
# Epoch 00032: val_loss did not improve from 0.00156
# Epoch 33/100
# 583/583 [==============================] - 0s 395us/step - loss: 0.0078 - val_loss: 0.0017
#
# Epoch 00033: val_loss did not improve from 0.00156
# Epoch 34/100
# 583/583 [==============================] - 0s 382us/step - loss: 0.0086 - val_loss: 0.0018
#
# Epoch 00034: val_loss did not improve from 0.00156
# Epoch 35/100
# 583/583 [==============================] - 0s 358us/step - loss: 0.0081 - val_loss: 0.0019
#
# Epoch 00035: val_loss did not improve from 0.00156
# Epoch 36/100
# 583/583 [==============================] - 0s 378us/step - loss: 0.0081 - val_loss: 0.0016
#
# Epoch 00036: val_loss improved from 0.00156 to 0.00156, saving model to saved_models/model_epoch_36.hdf5
# Epoch 37/100
# 583/583 [==============================] - 0s 354us/step - loss: 0.0075 - val_loss: 0.0015
#
# Epoch 00037: val_loss improved from 0.00156 to 0.00150, saving model to saved_models/model_epoch_37.hdf5
# Epoch 38/100
# 583/583 [==============================] - 0s 352us/step - loss: 0.0078 - val_loss: 0.0017
#
# Epoch 00038: val_loss did not improve from 0.00150
# Epoch 39/100
# 583/583 [==============================] - 0s 365us/step - loss: 0.0072 - val_loss: 0.0016
#
# Epoch 00039: val_loss did not improve from 0.00150
# Epoch 40/100
# 583/583 [==============================] - 0s 359us/step - loss: 0.0081 - val_loss: 0.0016
#
# Epoch 00040: val_loss did not improve from 0.00150
# Epoch 41/100
# 583/583 [==============================] - 0s 446us/step - loss: 0.0079 - val_loss: 0.0015
#
# Epoch 00041: val_loss did not improve from 0.00150
# Epoch 42/100
# 583/583 [==============================] - 0s 357us/step - loss: 0.0076 - val_loss: 0.0016
#
# Epoch 00042: val_loss did not improve from 0.00150
# Epoch 43/100
# 583/583 [==============================] - 0s 328us/step - loss: 0.0072 - val_loss: 0.0015
#
# Epoch 00043: val_loss improved from 0.00150 to 0.00150, saving model to saved_models/model_epoch_43.hdf5
# Epoch 44/100
# 583/583 [==============================] - 0s 318us/step - loss: 0.0073 - val_loss: 0.0015
#
# Epoch 00044: val_loss did not improve from 0.00150
# Epoch 45/100
# 583/583 [==============================] - 0s 325us/step - loss: 0.0072 - val_loss: 0.0015
#
# Epoch 00045: val_loss did not improve from 0.00150
# Epoch 46/100
# 583/583 [==============================] - 0s 308us/step - loss: 0.0074 - val_loss: 0.0014
#
# Epoch 00046: val_loss improved from 0.00150 to 0.00144, saving model to saved_models/model_epoch_46.hdf5
# Epoch 47/100
# 583/583 [==============================] - 0s 314us/step - loss: 0.0072 - val_loss: 0.0015
#
# Epoch 00047: val_loss did not improve from 0.00144
# Epoch 48/100
# 583/583 [==============================] - 0s 311us/step - loss: 0.0072 - val_loss: 0.0016
#
# Epoch 00048: val_loss did not improve from 0.00144
# Epoch 49/100
# 583/583 [==============================] - 0s 325us/step - loss: 0.0069 - val_loss: 0.0018
#
# Epoch 00049: val_loss did not improve from 0.00144
# Epoch 50/100
# 583/583 [==============================] - 0s 329us/step - loss: 0.0063 - val_loss: 0.0015
#
# Epoch 00050: val_loss did not improve from 0.00144
# Epoch 51/100
# 583/583 [==============================] - 0s 342us/step - loss: 0.0071 - val_loss: 0.0014
#
# Epoch 00051: val_loss improved from 0.00144 to 0.00142, saving model to saved_models/model_epoch_51.hdf5
# Epoch 52/100
# 583/583 [==============================] - 0s 318us/step - loss: 0.0068 - val_loss: 0.0014
#
# Epoch 00052: val_loss improved from 0.00142 to 0.00140, saving model to saved_models/model_epoch_52.hdf5
# Epoch 53/100
# 583/583 [==============================] - 0s 321us/step - loss: 0.0070 - val_loss: 0.0014
#
# Epoch 00053: val_loss did not improve from 0.00140
# Epoch 54/100
# 583/583 [==============================] - 0s 328us/step - loss: 0.0063 - val_loss: 0.0015
#
# Epoch 00054: val_loss did not improve from 0.00140
# Epoch 55/100
# 583/583 [==============================] - 0s 360us/step - loss: 0.0069 - val_loss: 0.0014
#
# Epoch 00055: val_loss did not improve from 0.00140
# Epoch 56/100
# 583/583 [==============================] - 0s 330us/step - loss: 0.0068 - val_loss: 0.0014
#
# Epoch 00056: val_loss improved from 0.00140 to 0.00137, saving model to saved_models/model_epoch_56.hdf5
# Epoch 57/100
# 583/583 [==============================] - 0s 314us/step - loss: 0.0075 - val_loss: 0.0017
#
# Epoch 00057: val_loss did not improve from 0.00137
# Epoch 58/100
# 583/583 [==============================] - 0s 339us/step - loss: 0.0060 - val_loss: 0.0015
#
# Epoch 00058: val_loss did not improve from 0.00137
# Epoch 59/100
# 583/583 [==============================] - 0s 337us/step - loss: 0.0058 - val_loss: 0.0014
#
# Epoch 00059: val_loss did not improve from 0.00137
# Epoch 60/100
# 583/583 [==============================] - 0s 345us/step - loss: 0.0071 - val_loss: 0.0016
#
# Epoch 00060: val_loss did not improve from 0.00137
# Epoch 61/100
# 583/583 [==============================] - 0s 317us/step - loss: 0.0066 - val_loss: 0.0013
#
# Epoch 00061: val_loss improved from 0.00137 to 0.00134, saving model to saved_models/model_epoch_61.hdf5
# Epoch 62/100
# 583/583 [==============================] - 0s 317us/step - loss: 0.0065 - val_loss: 0.0015
#
# Epoch 00062: val_loss did not improve from 0.00134
# Epoch 63/100
# 583/583 [==============================] - 0s 315us/step - loss: 0.0057 - val_loss: 0.0013
#
# Epoch 00063: val_loss improved from 0.00134 to 0.00131, saving model to saved_models/model_epoch_63.hdf5
# Epoch 64/100
# 583/583 [==============================] - 0s 316us/step - loss: 0.0059 - val_loss: 0.0013
#
# Epoch 00064: val_loss improved from 0.00131 to 0.00128, saving model to saved_models/model_epoch_64.hdf5
# Epoch 65/100
# 583/583 [==============================] - 0s 335us/step - loss: 0.0061 - val_loss: 0.0013
#
# Epoch 00065: val_loss did not improve from 0.00128
# Epoch 66/100
# 583/583 [==============================] - 0s 318us/step - loss: 0.0066 - val_loss: 0.0014
#
# Epoch 00066: val_loss did not improve from 0.00128
# Epoch 67/100
# 583/583 [==============================] - 0s 316us/step - loss: 0.0065 - val_loss: 0.0019
#
# Epoch 00067: val_loss did not improve from 0.00128
# Epoch 68/100
# 583/583 [==============================] - 0s 330us/step - loss: 0.0057 - val_loss: 0.0013
#
# Epoch 00068: val_loss improved from 0.00128 to 0.00127, saving model to saved_models/model_epoch_68.hdf5
# Epoch 69/100
# 583/583 [==============================] - 0s 314us/step - loss: 0.0054 - val_loss: 0.0013
#
# Epoch 00069: val_loss improved from 0.00127 to 0.00126, saving model to saved_models/model_epoch_69.hdf5
# Epoch 70/100
# 583/583 [==============================] - 0s 331us/step - loss: 0.0052 - val_loss: 0.0013
#
# Epoch 00070: val_loss did not improve from 0.00126
# Epoch 71/100
# 583/583 [==============================] - 0s 331us/step - loss: 0.0054 - val_loss: 0.0013
#
# Epoch 00071: val_loss did not improve from 0.00126
# Epoch 72/100
# 583/583 [==============================] - 0s 320us/step - loss: 0.0052 - val_loss: 0.0013
#
# Epoch 00072: val_loss did not improve from 0.00126
# Epoch 73/100
# 583/583 [==============================] - 0s 323us/step - loss: 0.0054 - val_loss: 0.0013
#
# Epoch 00073: val_loss did not improve from 0.00126
# Epoch 74/100
# 583/583 [==============================] - 0s 320us/step - loss: 0.0056 - val_loss: 0.0014
#
# Epoch 00074: val_loss did not improve from 0.00126
# Epoch 75/100
# 583/583 [==============================] - 0s 364us/step - loss: 0.0055 - val_loss: 0.0014
#
# Epoch 00075: val_loss did not improve from 0.00126
# Epoch 76/100
# 583/583 [==============================] - 0s 326us/step - loss: 0.0055 - val_loss: 0.0013
#
# Epoch 00076: val_loss did not improve from 0.00126
# Epoch 77/100
# 583/583 [==============================] - 0s 334us/step - loss: 0.0051 - val_loss: 0.0013
#
# Epoch 00077: val_loss did not improve from 0.00126
# Epoch 78/100
# 583/583 [==============================] - 0s 331us/step - loss: 0.0059 - val_loss: 0.0014
#
# Epoch 00078: val_loss did not improve from 0.00126
# Epoch 79/100
# 583/583 [==============================] - 0s 339us/step - loss: 0.0056 - val_loss: 0.0012
#
# Epoch 00079: val_loss improved from 0.00126 to 0.00124, saving model to saved_models/model_epoch_79.hdf5
# Epoch 80/100
# 583/583 [==============================] - 0s 346us/step - loss: 0.0053 - val_loss: 0.0013
#
# Epoch 00080: val_loss did not improve from 0.00124
# Epoch 81/100
# 583/583 [==============================] - 0s 313us/step - loss: 0.0052 - val_loss: 0.0014
#
# Epoch 00081: val_loss did not improve from 0.00124
# Epoch 82/100
# 583/583 [==============================] - 0s 338us/step - loss: 0.0054 - val_loss: 0.0012
#
# Epoch 00082: val_loss improved from 0.00124 to 0.00118, saving model to saved_models/model_epoch_82.hdf5
# Epoch 83/100
# 583/583 [==============================] - 0s 327us/step - loss: 0.0053 - val_loss: 0.0013
#
# Epoch 00083: val_loss did not improve from 0.00118
# Epoch 84/100
# 583/583 [==============================] - 0s 332us/step - loss: 0.0047 - val_loss: 0.0013
#
# Epoch 00084: val_loss did not improve from 0.00118
# Epoch 85/100
# 583/583 [==============================] - 0s 357us/step - loss: 0.0051 - val_loss: 0.0012
#
# Epoch 00085: val_loss did not improve from 0.00118
# Epoch 86/100
# 583/583 [==============================] - 0s 316us/step - loss: 0.0057 - val_loss: 0.0012
#
# Epoch 00086: val_loss did not improve from 0.00118
# Epoch 87/100
# 583/583 [==============================] - 0s 319us/step - loss: 0.0053 - val_loss: 0.0011
#
# Epoch 00087: val_loss improved from 0.00118 to 0.00114, saving model to saved_models/model_epoch_87.hdf5
# Epoch 88/100
# 583/583 [==============================] - 0s 320us/step - loss: 0.0054 - val_loss: 0.0012
#
# Epoch 00088: val_loss did not improve from 0.00114
# Epoch 89/100
# 583/583 [==============================] - 0s 315us/step - loss: 0.0050 - val_loss: 0.0011
#
# Epoch 00089: val_loss improved from 0.00114 to 0.00109, saving model to saved_models/model_epoch_89.hdf5
# Epoch 90/100
# 583/583 [==============================] - 0s 374us/step - loss: 0.0049 - val_loss: 0.0013
#
# Epoch 00090: val_loss did not improve from 0.00109
# Epoch 91/100
# 583/583 [==============================] - 0s 469us/step - loss: 0.0049 - val_loss: 0.0011
#
# Epoch 00091: val_loss did not improve from 0.00109
# Epoch 92/100
# 583/583 [==============================] - 0s 352us/step - loss: 0.0053 - val_loss: 0.0012
#
# Epoch 00092: val_loss did not improve from 0.00109
# Epoch 93/100
# 583/583 [==============================] - 0s 314us/step - loss: 0.0050 - val_loss: 0.0012
#
# Epoch 00093: val_loss did not improve from 0.00109
# Epoch 94/100
# 583/583 [==============================] - 0s 320us/step - loss: 0.0052 - val_loss: 0.0013
#
# Epoch 00094: val_loss did not improve from 0.00109
# Epoch 95/100
# 583/583 [==============================] - 0s 401us/step - loss: 0.0052 - val_loss: 0.0012
#
# Epoch 00095: val_loss did not improve from 0.00109
# Epoch 96/100
# 583/583 [==============================] - 0s 351us/step - loss: 0.0056 - val_loss: 0.0014
#
# Epoch 00096: val_loss did not improve from 0.00109
# Epoch 97/100
# 583/583 [==============================] - 0s 315us/step - loss: 0.0051 - val_loss: 0.0012
#
# Epoch 00097: val_loss did not improve from 0.00109
# Epoch 98/100
# 583/583 [==============================] - 0s 304us/step - loss: 0.0047 - val_loss: 0.0013
#
# Epoch 00098: val_loss did not improve from 0.00109
# Epoch 99/100
# 583/583 [==============================] - 0s 315us/step - loss: 0.0046 - val_loss: 0.0011
#
# Epoch 00099: val_loss did not improve from 0.00109
# Epoch 100/100
# 583/583 [==============================] - 0s 349us/step - loss: 0.0049 - val_loss: 0.0012
#
# Epoch 00100: val_loss did not improve from 0.00109
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_67 (LSTM)               (None, 50)                14200
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 14,251
# Trainable params: 14,251
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Why we chose the model at epoch 89
# The model at epoch 89 had the most similar training and validation losses, which implies that the model is not doing a lot of over or under fitting. As such, we load that model.

# %%
from keras.models import load_model

best_model = load_model('saved_models/model_epoch_89.hdf5')

# Predicting and inverse transforming the predictions

train_predict = best_model.predict(X_train)

Y_hat_train = scaler.inverse_transform(train_predict)

test_predict = best_model.predict(X_test)

Y_hat_test = scaler.inverse_transform(test_predict)

# Inverse transforming the actual values, to return them to their original values
Y_test = scaler.inverse_transform([Y_test])
Y_train = scaler.inverse_transform([Y_train])

# %%
Y_hat_train = np.reshape(Y_hat_train, newshape = 583)
Y_hat_test = np.reshape(Y_hat_test, newshape = 131)

Y_train = np.reshape(Y_train, newshape = 583)
Y_test = np.reshape(Y_test, newshape = 131)

# %% [markdown]
# # Evaluating Model Performance
# ## Computing the RMSE for the training and testing sets

# %%
from sklearn.metrics import mean_squared_error

train_RMSE = np.sqrt(mean_squared_error(Y_train, Y_hat_train))

test_RMSE = np.sqrt(mean_squared_error(Y_test, Y_hat_test))

print('Train RMSE is: ')
print(train_RMSE, '\n')
print('Test RMSE is: ')
print(test_RMSE)
# Out:
# Train RMSE is:
# 7.533530252818439
#
# Test RMSE is:
# 4.840542230289973

# %% [markdown]
# ## Visualizing the actual vs. predicted stock prices

# %%
Y = np.append(Y_train, Y_test)
Y_hat = np.append(Y_hat_train, Y_hat_test)

# %%
result_df = pd.DataFrame()

result_df['Actual_Y'] = Y
result_df['Predicted_Y'] = Y_hat


result_df.head()
# Out:
#      Actual_Y  Predicted_Y
# 0  181.410008   190.035355
# 1  177.110005   190.094711
# 2  178.729989   187.177917
# 3  174.420000   187.175049
# 4  178.380001   186.330902

# %%
result_df.plot()
